# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Import-Python-modules"><span class="toc-item-num">1 - </span>Import <code>Python</code> modules</a></div><div class="lev1"><a href="#Set-CONSTANTS"><span class="toc-item-num">2 - </span>Set <em>CONSTANTS</em></a></div><div class="lev1"><a href="#Create-Valuation-Model"><span class="toc-item-num">3 - </span>Create Valuation Model</a></div><div class="lev1"><a href="#Import-Data"><span class="toc-item-num">4 - </span>Import Data</a></div><div class="lev1"><a href="#Set-Outputs-to-Display"><span class="toc-item-num">5 - </span>Set Outputs to Display</a></div><div class="lev1"><a href="#Run-Valuation-Model"><span class="toc-item-num">6 - </span>Run Valuation Model</a></div>

# %% [markdown]
# # Import `Python` modules

# %%
from __future__ import print_function
import numpy
import pandas

from CorpFin.Valuation import UnlevValModel, LevValModel
from HelpyFuncs.Print import print_live_in_ipython
# Out:
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: CUDA driver version is insufficient for CUDA runtime version)
# WARNING:theano.sandbox.cuda:CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: CUDA driver version is insufficient for CUDA runtime version)

# %%
print_live_in_ipython()

# %% [markdown]
# # Set _CONSTANTS_

# %%
# Year 0
YEAR_0 = 1987

# Number of Pro-Forma Years EXCLUDING Year 0
NB_PRO_FORMA_YEARS = 8

# U.S. Corporate Tax rate
US_CORP_TAX_RATE = .35

# CAPM Parameters
RISK_FREE_RATE = .07
PUBLIC_MARKET_PREMIUM = .08
SCHOOL_ASSET_BETA = 1.

# Long-Term Growth Rate
LONG_TERM_GROWTH_RATE = .04

# %% [markdown]
# # Create Valuation Model

# %%
unlev_model = \
    UnlevValModel(
        venture_name='StLouisTech',
        year_0=YEAR_0,
        nb_pro_forma_years_excl_0=NB_PRO_FORMA_YEARS)

print()

lev_model = \
    LevValModel(unlev_model)
# Out:
# Compiling:
#     PublicMarketPremium... done after 0:00:00 (0:00:00 so far)
#     ProFormaPeriodAssetDiscountRate... done after 0:00:00 (0:00:00 so far)
#     ProFormaPeriodDiscountRate... done after 0:00:00 (0:00:00 so far)
#     StabilizedDiscountRate... done after 0:00:00 (0:00:00 so far)
#     Revenue... done after 0:00:00 (0:00:00 so far)
#     RevenueChange... done after 0:00:00 (0:00:00 so far)
#     RevenueGrowth... done after 0:00:00 (0:00:01 so far)
#     OpEx... done after 0:00:00 (0:00:01 so far)
#     OpEx_over_Revenue... done after 0:00:00 (0:00:02 so far)
#     OpExGrowth... done after 0:00:00 (0:00:02 so far)
#     EBIT... done after 0:00:00 (0:00:02 so far)
#     EBITMargin... done after 0:00:00 (0:00:03 so far)
#     EBITGrowth... done after 0:00:00 (0:00:04 so far)
#     EBIAT... done after 0:00:01 (0:00:05 so far)
#     FA... done after 0:00:00 (0:00:05 so far)
#     FA_over_Revenue... done after 0:00:01 (0:00:06 so far)
#     FAGrowth... done after 0:00:01 (0:00:07 so far)
#     Depreciation... done after 0:00:00 (0:00:08 so far)
#     Depreciation_over_prevFA... done after 0:00:00 (0:00:09 so far)
#     CapEx... done after 0:00:05 (0:00:15 so far)
#     CapEx_over_Revenue... done after 0:00:05 (0:00:20 so far)
#     CapEx_over_RevenueChange... done after 0:00:05 (0:00:26 so far)
#     CapExGrowth... done after 0:00:11 (0:00:37 so far)
#     NWC... done after 0:00:00 (0:00:38 so far)
#     NWC_over_Revenue... done after 0:00:00 (0:00:39 so far)
#     NWCGrowth... done after 0:00:01 (0:00:40 so far)
#     NWCChange... done after 0:00:01 (0:00:41 so far)
#     NWCChange_over_Revenue... done after 0:00:02 (0:00:43 so far)
#     NWCChange_over_RevenueChange... done after 0:00:01 (0:00:45 so far)
#     FCF... done after 0:00:08 (0:00:54 so far)
#     TV... done after 0:00:02 (0:00:56 so far)
#     TV_RevenueMultiple... done after 0:00:02 (0:00:59 so far)
#     TV_EBITMultiple... done after 0:00:03 (0:01:03 so far)
#     Unlev_Val... done after 0:00:26 (0:01:30 so far)
# done after 0:01:30
#
# Compiling:
#     ProFormaPeriodITSDiscountRate... done after 0:00:00 (0:00:00 so far)
#     StabilizedITSDiscountRate... done after 0:00:00 (0:00:00 so far)
#     Unlev_Val... done after 0:00:00 (0:00:00 so far)
#     DERatios... done after 0:00:00 (0:00:00 so far)
#     Debt... done after 0:00:00 (0:00:00 so far)
#     InterestRates... done after 0:00:00 (0:00:00 so far)
#     InterestExpense... done after 0:00:00 (0:00:00 so far)
#     ITS... done after 0:00:00 (0:00:00 so far)
#     ITS_TV... done after 0:00:00 (0:00:00 so far)
#     Val_of_ITS_incl_TV... done after 0:00:00 (0:00:00 so far)
#     Lev_Val... done after 0:00:00 (0:00:01 so far)
# done after 0:00:01

# %% [markdown]
# # Import Data

# %%
data_df = \
    pandas.read_csv(
        'data/St. Louis Institute of Technology.csv',
        index_col='Year')
    
data_df.T
# Out:
# Year                 1988  1989  1990  1991  1992  1993  1994  1995
# Revenue              4300  4945  5687  6255  6818  7432  8101  8830
# Depreciation          180   180   180   180   180   180   180   180
# EBIT                  680   809   957  1196  1388  1604  1764  1939
# CapEx_and_NWCChange   120   202   207   198   208   211   213   216
# Interest              324   324   314   304   292   280   266   140

# %% [markdown]
# # Set Outputs to Display

# %%
unlev_outputs = \
    ['RiskFreeRate', 'PublicMarketPremium',
     ' ',
     'ProFormaPeriodBeta', 'ProFormaPeriodDiscountRate',
     '  ',
     'StabilizedBeta', 'StabilizedDiscountRate',
     '   ',
     'REVENUE calcs:', 'Revenue', 'RevenueGrowth',
     '    ',
     'EBIT calcs:', 'EBIT', 'EBITMargin', 'EBITGrowth',
     '     ',
     'EBIAT calcs:', 'CorpTaxRate', 'EBIAT',
     '      ',
     'Depreciation',
     '       ',
     'CAPEX & NET WORKING CAPITAL calcs:', 'CapEx',
     '        ',
     'FCF & TV calcs:', 'FCF', 'LongTermGrowthRate', 'TV', 'TV_RevenueMultiple', 'TV_EBITMultiple',
     '         ',
     'UNLEVERAGED VALUATION calcs:', 'Unlev_Val']

lev_outputs = \
    ['          ',
     'INTEREST TAX SHIELD (ITS) calcs:', 'InterestExpense', 'ITS', 'ITS_TV', 'Val_of_ITS_incl_TV',
     '           ',
     'LEVERAGED VALUATION calcs:', 'Lev_Val']

# %% [markdown]
# # Run Valuation Model

# %%
inputs = \
    dict(
        Revenue=[3955] + data_df.Revenue.tolist(),
        EBIT=[446] + data_df.EBIT.tolist(),
        CorpTaxRate=US_CORP_TAX_RATE,
        Depreciation=[180] + data_df.Depreciation.tolist(),
        CapEx=[100] + data_df.CapEx_and_NWCChange.tolist(),
        RiskFreeRate=RISK_FREE_RATE,
        PublicMarketPremium=PUBLIC_MARKET_PREMIUM,
        ProFormaPeriodBeta=SCHOOL_ASSET_BETA,
        StabilizedBeta=SCHOOL_ASSET_BETA,
        LongTermGrowthRate=LONG_TERM_GROWTH_RATE,
        InterestExpense=[62] + data_df.Interest.tolist())

unlev_results = \
    unlev_model(
        outputs=unlev_outputs,
        **inputs)

print()

lev_results = \
    lev_model(
        outputs=lev_outputs,
        append_to_results_data_frame=unlev_results['data_frame'],
        Unlev_Val=unlev_results['Unlev_Val'],
        **inputs)

pandas.options.display.float_format = '{:,.2f}'.format
lev_results['data_frame'].T
# Out:
# Calculating:
#     PublicMarketPremium
#     ProFormaPeriodDiscountRate
#     StabilizedDiscountRate
#     Revenue
#     RevenueGrowth
#     EBIT
#     EBITMargin
#     EBITGrowth
#     EBIAT
#     Depreciation
#     CapEx
#     FCF
#     TV
#     TV_RevenueMultiple
#     TV_EBITMultiple
#     Unlev_Val
# done!
#
# Calculating:
#     InterestExpense
#     ITS
#     ITS_TV
#     Val_of_ITS_incl_TV
#     Lev_Val
# done!
#                                      Year 0     1988     1989     1990  \
# RiskFreeRate                           0.07
# PublicMarketPremium                    0.08
#
# ProFormaPeriodBeta                     1.00
# ProFormaPeriodDiscountRate             0.15
#
# StabilizedBeta                         1.00
# StabilizedDiscountRate                 0.15
#
# REVENUE calcs:
# Revenue                            3,955.00 4,300.00 4,945.00 5,687.00
# RevenueGrowth                           NaN     0.09     0.15     0.15
#
# EBIT calcs:
# EBIT                                 446.00   680.00   809.00   957.00
# EBITMargin                             0.11     0.16     0.16     0.17
# EBITGrowth                              NaN     0.52     0.19     0.18
#
# EBIAT calcs:
# CorpTaxRate                            0.35
# EBIAT                                289.90   442.00   525.85   622.05
#
# Depreciation                         180.00   180.00   180.00   180.00
#
# CAPEX & NET WORKING CAPITAL calcs:
# CapEx                                100.00   120.00   202.00   207.00
#
# FCF & TV calcs:
# FCF                                  369.90   502.00   503.85   595.05
# LongTermGrowthRate
# TV
# TV_RevenueMultiple
# TV_EBITMultiple
#
# UNLEVERAGED VALUATION calcs:
# Unlev_Val                          7,117.92
#
# INTEREST TAX SHIELD (ITS) calcs:
# InterestExpense                       62.00   324.00   324.00   314.00
# ITS                                   21.70   113.40   113.40   109.90
# ITS_TV
# Val_of_ITS_incl_TV                   568.44
#
# LEVERAGED VALUATION calcs:
# Lev_Val                            7,686.35
#
#                                        1991     1992     1993     1994  \
# RiskFreeRate
# PublicMarketPremium
#
# ProFormaPeriodBeta
# ProFormaPeriodDiscountRate
#
# StabilizedBeta
# StabilizedDiscountRate
#
# REVENUE calcs:
# Revenue                            6,255.00 6,818.00 7,432.00 8,101.00
# RevenueGrowth                          0.10     0.09     0.09     0.09
#
# EBIT calcs:
# EBIT                               1,196.00 1,388.00 1,604.00 1,764.00
# EBITMargin                             0.19     0.20     0.22     0.22
# EBITGrowth                             0.25     0.16     0.16     0.10
#
# EBIAT calcs:
# CorpTaxRate
# EBIAT                                777.40   902.20 1,042.60 1,146.60
#
# Depreciation                         180.00   180.00   180.00   180.00
#
# CAPEX & NET WORKING CAPITAL calcs:
# CapEx                                198.00   208.00   211.00   213.00
#
# FCF & TV calcs:
# FCF                                  759.40   874.20 1,011.60 1,113.60
# LongTermGrowthRate
# TV
# TV_RevenueMultiple
# TV_EBITMultiple
#
# UNLEVERAGED VALUATION calcs:
# Unlev_Val
#
# INTEREST TAX SHIELD (ITS) calcs:
# InterestExpense                      304.00   292.00   280.00   266.00
# ITS                                  106.40   102.20    98.00    93.10
# ITS_TV
# Val_of_ITS_incl_TV
#
# LEVERAGED VALUATION calcs:
# Lev_Val
#
#                                         1995
# RiskFreeRate
# PublicMarketPremium
#
# ProFormaPeriodBeta
# ProFormaPeriodDiscountRate
#
# StabilizedBeta
# StabilizedDiscountRate
#
# REVENUE calcs:
# Revenue                             8,830.00
# RevenueGrowth                           0.09
#
# EBIT calcs:
# EBIT                                1,939.00
# EBITMargin                              0.22
# EBITGrowth                              0.10
#
# EBIAT calcs:
# CorpTaxRate
# EBIAT                               1,260.35
#
# Depreciation                          180.00
#
# CAPEX & NET WORKING CAPITAL calcs:
# CapEx                                 216.00
#
# FCF & TV calcs:
# FCF                                 1,224.35
# LongTermGrowthRate                      0.04
# TV                                 11,575.67
# TV_RevenueMultiple                      1.31
# TV_EBITMultiple                         5.97
#
# UNLEVERAGED VALUATION calcs:
# Unlev_Val
#
# INTEREST TAX SHIELD (ITS) calcs:
# InterestExpense                       140.00
# ITS                                    49.00
# ITS_TV                                326.67
# Val_of_ITS_incl_TV
#
# LEVERAGED VALUATION calcs:
# Lev_Val
